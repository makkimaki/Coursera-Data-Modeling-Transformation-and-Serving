# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import tensorflow_datasets as tfds

# %%
dataset = tfds.load('cats_vs_dogs', split='train', as_supervised=True)

for image, label in dataset.take(1):
  plt.imshow(image)
  print(image.shape, label)
  print(label)
# Out:
# Downloading and preparing dataset 786.67 MiB (download: 786.67 MiB, generated: 1.04 GiB, total: 1.81 GiB) to /root/tensorflow_datasets/cats_vs_dogs/4.0.1...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Generating splits...:   0%|          | 0/1 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/23262 [00:00<?, ? examples/s]
# WARNING:absl:1738 images were corrupted and were skipped
# Shuffling /root/tensorflow_datasets/cats_vs_dogs/incomplete.FMRDA2_4.0.1/cats_vs_dogs-train.tfrecord*...:   0%…
# Dataset cats_vs_dogs downloaded and prepared to /root/tensorflow_datasets/cats_vs_dogs/4.0.1. Subsequent calls will reuse this data.
# (262, 350, 3) tf.Tensor(1, shape=(), dtype=int64)
# tf.Tensor(1, shape=(), dtype=int64)

# %%
IMG_SIZE = 150

# %%
def resize_normalize(image, label):
  # resize the image
  image = tf.image.resize(image, [IMG_SIZE, IMG_SIZE])
  # normalize the image
  image = (image / 255.0)
  return image, label

# %%
dataset = dataset.map(resize_normalize)

# %%
for image, label in dataset.take(1):
  plt.imshow(image)
  print(image.shape, label)
# Out:
# (150, 150, 3) tf.Tensor(1, shape=(), dtype=int64)

# %%
image, label = next(iter(dataset))

# %%
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(tf.image.flip_left_right(image))

# %%
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(tf.image.rot90(image))

# %%
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(tf.image.random_brightness(image, max_delta=0.5))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.09823036..1.0982304].

# %%
def augment(image, label):
  image = tf.image.random_flip_left_right(image)
  image = tf.image.rot90(image)
  #image = tf.image.random_contrast(image, lower=0.2, upper=0.8)
  image = tf.image.random_brightness(image, max_delta=0.5)
  return image, label

# %%
plt.subplot(1, 2, 1)
plt.imshow(image)
plt.subplot(1, 2, 2)
plt.imshow(augment(image, label)[0])
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.19544387..1.1954439].
